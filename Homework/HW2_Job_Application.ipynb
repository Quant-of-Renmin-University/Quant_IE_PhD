# %% [markdown]
# # Job Applications Letters Generator
#
# - Purpose: when we try to apply jobs from companies, the statement of purpose will take us tremendous time. To save time, we can use python to generate multiple copies of statement of purpose with slight modification.
# - Target Audience: Graduate students who are looking for jobs.
#
# - Details:
#     - step1 : find a application letter template by using online
#     - step2 : replace the personal information with your own personal information to get a `MS Word template` (one pager)
#     - step3 : create a `excel list` of 10 companies from glassdor.com [https://www.glassdoor.com.hk/Job/index.htm]
#     - step4: create a `excel list` of 5 job positions you want to apply [https://www.glassdoor.com.hk/Job/index.htm]
#     - step5 : add the `excel list` from step4 of top journals for each research areas for each job position (3 for each area, https://journalranking.org/)
#     - step6 : add the `excel list` from step4 of the skills for each job positionyou search from (Glassdoor Job)[https://www.glassdoor.com.hk/Job/index.htm]
#     - step7 : Loop over the two lists aforementioned to fill the template.
#     - step8 : use docxtpl to generate the MS Word document
#
#     - step9 : use docx2pdf to generate the PDF document (only for the windows users)
#     - step10 : create a subdir named "HW_Job_Application" under your home dir and upload your `your codes, excel list, Word template and only 1 copy of PDF or WORD` to ***GitHub***  by next class

# %% [markdown]
# Example:
#
# Dear Data Science Team,
#
# My name is Ray Ge, and I am pleased to apply for the `Data Scientist` at `Microsoft`.
#
# In my free time, I enjoy reading top-tier academic research to stay updated with the latest advancements of quantitative research in `finance`. I occasionally study articles from leading ABS 4+ rated journals such as the `Review of Financial Studies (RES), Journal of Finance (JF), and Management Science (MS)`, among others. This habit not only deepens my understanding of theoretical and empirical approaches in finance but also sharpens my ability to critically analyze complex economic phenomena.
#
# I want to be a `Data Scientist`. To achive my dream, I have practical skills such as `Python, SQL, Math, PowerBI, Tableau and etc`.
#
# I am particularly drawn to `Microsoft` due to its strong academic environment and research-oriented approach.
#
# Thank you for considering my application.
# Sincerely,
#
# Ray Ge
#
#
#
#
#
#
#
# - TOOLS: function, loop, docxtpl, docx2pdf
# - Results: you get a 90 copies of statement of purpose
