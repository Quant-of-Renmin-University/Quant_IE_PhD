# %%
from transformers import TRANSFORMERS_CACHE
# Out:
# /home/hmai/anaconda3/lib/python3.13/site-packages/transformers/utils/hub.py:111: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
TRANSFORMERS_CACHE
# Out:
# '/home/hmai/models'
